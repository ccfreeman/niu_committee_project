# %%
import requests
from bs4 import BeautifulSoup

import re

import numpy as np
import pandas as pd

# %%
def parse_ul(ul, df):
    """
    Function to parse the series of tags labeled 'ul'. Each contains two
    pieces of information: (i) the name of the committee and (ii) the link
    to the committee page. 
    
    Returns: a dataframe with the columns 'name' and 'link' filled in.
    """
    committee_list = ul.find_all()
    for committee in committee_list:
        if committee.name == 'a':
            row = {'name': committee.text, 'link': committee['href']}
            df = df.append(row, ignore_index=True)
    return df

def follow_links(df, base_url):
    """
    Follows the links given in a column from the dataframe given as argument.
    Scrapes tables from the committee pages and records them in dataframes.
    
    Returns: a dictionary of key:value pairs, where keys are committee names and
    values are the tables. In two instances, there are multiple tables, for which
    we record the tables in a list of items
    """
    tables = {}
    for i in df.index.values:
        if df.loc[i, 'link'][-6:] == '.shtml':
            url = base_url + df.loc[i, 'link']
            r = requests.get(url)
            soup = BeautifulSoup(r.content, 'html5lib')
            table = soup.find_all('table')
            
            tables[df.loc[i, 'name']] = []
            if len(table) > 1:
                if df.loc[i, 'name'] == 'Faculty Senate':
                    # 'Faculty Senate' has multiple tables and a different form (header is different 
                    # on both tables); requires different read-in
                    for j, tab in enumerate(table):
                        tables[df.loc[i, 'name']].append(pd.read_html(str(table), header=1)[j])
                else:
                    # Else just iterate through tables and read them in as usual
                    for j, tab in enumerate(table):
                        tables[df.loc[i, 'name']].append(pd.read_html(str(table), header=0)[j])
            else:            
                try:
                    tables[df.loc[i, 'name']].append(pd.read_html(str(table), header=0)[0])
                except:
                    continue
            
    return tables

# %%
# Request html for the committee's homepage
url = "https://www.niu.edu/u_council/committees/"
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content, 'html5lib')
# print(soup.prettify())

# %%
# First, follow the html code tree to the tags labeled 'ul'. These
# contain the links for the committees we are interested in scraping
links = soup.find('div', attrs={'id':'mainContent'})
links = links.find('div', attrs={'id':'contentwithleftnav'})
links = links.find('contenttext')
links = links.find_all('ul')

# Create a dataframe to hold the results of the committees and links
df = pd.DataFrame(columns=['name', 'link'])

# Use the function parse_ul() to fill in the dataframe
for i in range(len(links)):
    df = parse_ul(links[i], df)

# %%
# Now we follow those links and scrape the tables from each page
# using our follow_links() function. 
tables = follow_links(df, url)

# %%
# tables['Faculty Senate'][0]

# %%
com_members = {}
for committee in tables.keys():
    for table in tables[committee]:
        # Make sure to drop nan values before adding people
        if '2019-2020' in table.columns.values:
            members = table['2019-2020'].dropna().values
        else:
            members = table['2019-20'].dropna().values
            
        for member in members:
            
            # Remove anything between parentheses (including the parentheses)
            member = re.sub(r" \(\S*\)|\**|#|^x\S*\s*|\Ax", "", member)
            member = re.sub(r"\xa0", " ", member)
            member = re.sub(r"^x", "", member)
            if member == "2019-2020":
                continue
            if member in com_members:
                com_members[member].append(committee)
            else:
                com_members[member] = [committee]

# %%
for key in com_members.keys():
    print(key)
# Out:
# Nan Qin
# Peter Chomentowski, Chair
# Veysel Demir
# Amanda McCarthy
# Mark Schuller (for Irwin)
# Rich Grund
# Beth Ingram
# Geoffrey Gordon
# Brad Cripe
# Chad McEvoy
# Cynthia Campbell
# Donald Zinger
# Mahdi Vaezi
# Hamid Bateni
# Bette Montgomery for Ysasi
# Marc Falkoff
# Brad Peters
# Kurt Thurmaier for Matuszewich
# Evgueni Nesterov for Stephen
# Judith Chitwood
# John Siblik
# Omar Ghrayeb
# Gerald Blazey
# Carolinda Douglass
# Sue Mini
# Fred Barnhart
# Brad Bond
# J. Daniel House
# Ritu Subramony
# Jeff Reynolds
# James Burton
# Vicki Collins, Chair
# Jie Chen
# Amy Newman
# Omar Chmaissem
# Jim Wilson
# Alan Polansky
# Judy Ledgerwood
# Derryl Block
# Omar Ghrayeb, Vice Provost for Undergraduate Academic Affairs
# Amari White
# Megan Rooney
# Mark Groza
# Tim Aurand
# Erika Pinter
# Joe Bittorf
# Josephine Umoren
# Michael Oswalt
# Mike Konen
# TBD for Ladell
# Thomas Bough
# Kamron Smith
# Amberly Rodriguez
# Pete Garrity
# Glenn Roby
# Lesley Gilbert for Nay
# TBD for Salmon
# Sean Frazier
# Laura Sala
# Aidan Shields
# Amanda Ferguson
# Sina Ethsani
# Laura Hedin
# Rod Caughron
# Ji-Chul Ryu
# Liping Guo
# Eunha Myung
# Fall-Josephine Umoren for GeigerSpring-Sarah Geiger
# Meg Cheng
# Steven Daskal
# David Gorman
# Alexandra Bennett
# John Wolfskill for Johns
# Melissa Lenczewski
# Janet Hathaway
# Wayne Finley
# Katy Jaekel
# Glenn "Agape" Montero, CHHS
# Colette Maher
# Michael Zajac
# Crystal Garvey
# Katy Saalfeld
# John Evar Strid
# Betty La France
# Jason Akst
# Vicki Wronkowski
# Karen Smith
# Anthony Calderala
# Tim Trottier for Lorusso
# TBD for Baumgart
# Carmorroa SiggersDevohn Hall
# Ben Ritter
# Joe Przybyla
# Michael Rothamer
# Sue Bidstrup
# Tim Condon
# Matt Parks
# Jennifer Manning / Charles Cherry
# Rachel Xidis
# J. Royce
# Dave Scharenberg
# Donald Rodman
# Joe Talbert
# Ken George
# Vicki Collins
# Wendy Vaughn
# Tom Kazmierczak
# Cody Carter
# M. Eugene Massey
# Wieteke Holthuijzen
# Cassandra Pilcher
# John Petragallo
# Thomas R. Phillips, Sr., CVPC ChairpersonChief of Police
# Donald RodmanCommander of Support Services
# Kendall ThuFaculty Senate President
# Sue MiniVice Provost for Resources and Planning
# Kelly Wesener MichaelAssociate Vice President for Student Affairs
# Richard WardEmergency Management Coordinator
# Brooke RuxtonExecutive Director
# Brian SmithDirector, Employee Assistance Program
# Dan PedersenSenior Director
# Bryan PerryGeneral Counsel
# Jason LevertonCommander of Administration
# Mary Ellen SchaidExecutive Director
# Rick AmatoDeKalb County State's Attorney
# Linda Yasui
# Jim Horn
# Yasuo Ito
# Todd Gilson
# Justin Bitner
# Ellen Olsen
# Theodore Hogan
# Joshua Schwartz
# Michele Crase
# Beth Reiter
# Scott Mooberry
# Leslie Matuszewich
# Vernese Edghill-Walden
# Anne EdwardsJoseph Flynn
# Christina Abreau
# Kate Cady
# Eric Jones
# Deb Miller
# Sherry Fang
# Ed KlonoskiMichelle Pickett
# Carolyn Davis
# Sarah Marsh
# Dana Isawi
# Benedito Fonseca
# Kari Hickey / Merlynette Griffin
# Janice Hamlet
# Meredith Stange for Pettitt
# Paula Frasz
# Greg Barker
# TBD for Pickett
# Tamara Boston
# Ed Klonoski
# Elisa Frederidcks
# Daryl Dugas
# Venumadhav Korampally
# Sheila Barrett
# Trude Jacobsen
# TBD for Katja Wiemer
# Cindy Hellyer-Heinz
# Sarah Holmes
# Jeanne Baxter
# Michelle Bringas
# Kelly Olson
# Zac Birch
# Andrea Radasanu
# TBD
# Fall-Todd Reeves (for Johnson)Spring-Laura Johnson
# Fall-TBD for MoragaSpring-Reinaldo Moraga
# Jamie Mayer
# Chong Zheng
# Heidi Kuehl
# Todd Buck
# Kendall Thu
# Tim Webster
# Mike Kuba
# Matt Pickard
# Todd Reeves
# Shun Takai
# Bryan Dallas
# Sharon Nelson
# Joseph Scudder
# Matthew Short
# Rahul Thatte
# Saurav Mukhopadhyay
# Bill Pitney
# Jerry Blazey
# Balaji Rajagopalan
# Laurie Elish-Piper
# Donald Peterson
# Laurel Rigertas
# Paul Kassel
# Kelly Wesener-Michael
# Laura Alexander
# Ann Dzuranin
# Jodi Lampi
# Lichuan Liu
# Kari Hickey for Abendroth
# Therese Arado
# Pallavi Singh for Reyman
# Wei Luo
# Leanne VandeCreek
# Jason Rhode
# John Pendergrass
# Katy Jaekel, Chair
# Sahar Vahabzadeh
# Arlene Keddie
# Florensia Surjadi
# Karen Whedbee
# Ross Powell
# Jason Hanna
# Beth McGowan
# Greg Beyer
# Devaki Rau
# Christine Mooney for Patro
# William Penrod for Hunt
# Melanie Koss for Rheineck
# So-Yeun Kim
# Kevin Martin
# Gary Chen
# Fall-Reinaldo MoragaSpring-Jenn-Terng Gau
# Lin Shi
# Anne Hanley
# Sean Farrell
# Scot Schraufnagel for Song
# Simón Weffer
# Reed Scherer
# Alicia Schatteman for Stephen
# Amanda Littauer
# Jim Millhorn
# Kryssi Staikidis for Hathaway
# Richard Siegesmund
# Patricia Skarbinski
# Greg Beyer for Boughton
# Mark Riley
# Nan Qin for Zheng
# Mahesh Subramony
# Elisa Fredericks
# Fall-Todd ReevesSpring-Laura Johnson
# Peter Chomentowski
# Benjamin Creed
# Sarah Johnston-Rodriguez
# Fall-TBDSpring-Reinaldo Moraga
# Bob Tatara
# Amanda McCarthy for Sprong
# Nancy Petges for Beamer
# Mark Schuller for Irwin
# Jozef Bujarski
# Chong Zheng for Baker
# Kirk Duffin
# George Slotsve
# Doris Macdonald
# Ismael Montana
# Gleb Sirotkin
# Dhiman Chakraborty
# Fall-Kheang UnSpring-April Clark
# Keith Millis
# Jaehee Jong for Schatteman
# Shane Sharp
# Lei Hua
# Fall-Joanna KotSpring-Tharaphi Than
# TBD for Beyer
# FACULTY SENATEOTHER MEMBERS AND CONSULTANTS
# Alex Gelman
# Linda Saborio for Stoddard
# Catherine Doederlein
# Carrie Kortegast
# Jeffry Royce
# Ferald Bryan
# Elisa Fredericks, At large
# Katy Jaekel, Chair, Faculty Rights and Responsibilities Committee
# Peter Chomentowski, Chair, Academic Affairs Committee
# Veysel Demir, At large
# Jamie Mayer, At large
# Kendall Thu, Faculty Senate President
# George Slotsve, FS Liaison/Spokesperson, Resources, Space and Budget Committee and FS Vice President
# Keith Millis, FS Liaison/Spokesperson, Rules, Governance and Elections Committee
# Heidi Kuehl, At large
# Beth McGowan, At large
# Todd Buck, At large
# ESOTP Chair
# Rod Coughron
# Melanie Walski
# Robert Sinko
# Bette Montgomery
# TBD for Lurio
# Emma Kuby for Huffine
# Michelle Pickett
# Edward Klonoski
# Yao Zheng
# Kate Mantzke
# Rodion Gavieta
# Clayton Camic
# Thomas Smith
# Stacy Kelly
# Darius Jackson
# Federico Sciammarella
# Steve Binderup
# Lynn Herrmann
# Kelly Furr
# Betty La France for Myers
# Jessica Reyman for Porter
# Mary Lynn Henningsen for Radasanu
# Courtney Gallaher
# Jeremy Groves
# Victor Ryzhov
# Michael Barnes
# Eric Johnson
# Matthew Werstler
# Nestor Osorio
# Bradley Bond
# Kate Mantzke, ACCY
# Steve Howell, KNPE
# Kelly Summers, LEPF
# John Shelton, MECH
# Tomoyuki Shibata, HLTH
# Betty La France, COMM
# Reed Scherer, GEOL
# Jeremy Floyd, MUSC
# Wieteke Holthuijzen, BIOS
# Denise Halverson
# Barton Sharp
# Leslie Sassone
# Nicholas Pohlman
# Nick Hryhorczuk
# Fall-TBD for SchraufnagelSpring-Scot Schraufnagel
# Timothy Crowley
# Barbara Gonzalez
# Anthony AcevedoCameron SimpsonElaina KinneyGrace DvorakKate James
# Naina Richards
# Ursula Sullivan
# Paul Wright
# Kyu Taek Cho
# Lynn Hermann
# David Taylor
# Terry McClellan
# Sarah Lindell
# Mark Frank
# David Scharenberg
# Shannon Stoker
# Mya Groza
# Euikyung Shin
# Sachit Butail
# Cristin Sabio
# Scot Schraufnagel
# Brian Hart
# Meredith Ayers
# Hailey Nailor
# Junlin Pan
# Mary Burns
# Wendell Johnson
# Rob Ridinger
# Bill Cassidy
# Joihn Pendergrass
# Tom Parisi
# Geo Williams-Mays
# Summer Ghoman
# Samantha Malone
# Anthony Barra
# Richard BaertPensions & Investments Newspaper(a Crains Communications publication)
# Matt ButeCars.com
# Mark BrownChicago Sun-Times
# Shelley Hendricks
# Amy Franklin
# Tom O'Grady
# Jessica Seipp
# TBD for Watson
# Antonio Johnson
# Sue Bidstrup/Jessica Totz
# Ana Calvo
# Nathan Stansell
# Larry Lurio
# Alicia Schatteman
# Therese Arado, Chair
# Ben Creed
# George Slotsve, FS Liaison/Spokesperson
# Naomi Bolden
# Cathy Doederlein
# Natasha Johnson
# Sarah McGill
# Richard Siegesmund, Chair
# Christine Mooney
# Keith Millis, FS Liaison/Spokesperson
# Ian Pearson
# James Burton, at large
# Vicki Collins, Chair, Academic Policy Committee
# Gary Chen, At large
# Hamid Bateni, Chair, University Affairs Committee
# Kendall Thu, Executive Secretary, University Council
# Therese Arado, Chair, Resources, Space and Budget Committee
# Jim Millhorn, At large
# Richard Siegesmund, Chair, Rules, Governance and Elections Committee
# Naomi Bolden, President, Student Association
# Ian Pearson, Speaker of the Senate, Student Association
# Cathy Doederlein, President, SPS Council
# Jeffry Royce, President, Operating Staff Council
# Laurie Elish-Piper, Dean, College of Education
# Fred Barnhart, Dean, University Libraries
# Jeanne Meyer
# Brian Glick
# Joy R. Mitchell
# Dan McConkie
# Lisa March
# Kristie Crane
# Kevin Schaeffer
# Don Rodman
# Danielle Young
# Monique Bernoudy
# Courtney Vinson
# Sarah Klaper
# Natalie Churyk
# Lisa Liberty for Zvosec
# Melissa Fickling for Summers
# William Mills
# Susan Bowers
# Paul Cain
# Keri Burchfield
# David Henningsen
# Lori Hartenhoff
# Anthony Devroye
# Kristie Crane for Noascono
# Trevor Rogneby
# Evelyn Comber
# Jeff Salmon for Olson
# Eric Armstrong
# Alex Pitner
# Andrea Drott for Gotto
# Bill Penrod
# Melanie Koss
# Hamid Bateni, Chair
# Sarah Garner, Ethics and Compliance Officer
# Shantez Branch
# Andrew Setterstrom
# Adam Carter
# Hasan Ferdowsi
# TBD for Hogan
# Hyun-Mee Joung
# Sheila Barrett for Abendroth
# Dennis Brain
# Alecia Santuzzi
# Brandon Lagana
# David Ballantine
# Tawanda Gipson
# Crystal Doyle
# Carrie Zack
# Therese Arado for Beamer
# Varsie Geisler
# Karen Smith for Calderala
# Deb Boughton
# Celeste Latham
# Toni Tollerud
# Liz Guess
# Lisa Freeman
# Kelly Wesener Michael
# Sol Jensen
# Naomoi Bolden
# Sanchez Branch
# Ashley Hines
# Victor Owoeye
# Lindsey David
# Delaney Drew
# Victoria Lang
# Stephen Binderup
# James Burton, MGMT
# Fall-So-Yeun Kim, KNPESpring-TBD
# Gary Chen, ISYE
# Hamid Bateni, AHCD
# Fall-Anne Hanley, HISTSpring-Sean Farrell, HIST
# Simon Weffer, SOCI, for Thu
# Richard Siegesmund, ARTD
# Charles Petersen, OMIS
# Fall-Myoungwhon Jung, SEEDSpring-James Cohen, CURR
# Robert Tatara, TECH
# Bryan Dallas, SIHP
# Robert Jones
# Alastair Fletcher, MATH
# Bill Goldenberg, MUSI
# 2019-20
# Anne Kaplan
# James Cohen
# Reinaldo Moraga
# Kathleen Coles
# Cynthia Hellyer-Heinz
# Jon Miller
# Amy Farranto
# Charles Downing
# Fall-TBDSpring-Patrick Roberts
# Ted Hogan
# Xiaohui Sophie Li
# Matt Timko
# Bill Cassidy for Ryan
# Christopher Einolf
# Andy Bruno
# Sarah Evans
# Shaokun Yu
# Lindsay Harris
# Ibrahim Abdel-Motaleb
# Manju Daniel
# Angela Grippo
# Ann Van Dijk
# Anne Hardy
# Craig Mulligan, College of BusinessSusan Mizgalski, College of EducationSandra Manisco, College of Engineering and Engineering TechnologyLori Botterman, College of Health and Human SciencesSharon Nelson, College of LawPaula Meyer, College of Liberal Arts and SciencesAndy Dolan, College of Visual and Performing ArtsSteffen Scharmacher, University Libraries
# Ann Kenney
# Katharine WhitelawNicole Wilson
# Jessica Adeoti, Web Team Neil Colwell, Web TeamDonnie Forti, Web TeamHolly Nicholson, Web TeamJory Keller, Web TeamJennice O'Brien, Web and Internal CommunicationsAndy Pemberton, Web and Internal CommunicationsLori Propheter, Web TeamEmily Salvani, Web Team/Brian Walk, Web TeamRachel Xidis, Web and Internal Communications
# Prashanth GurralaElson Smith
# See Marketing and Communications for employees with shared appointments
# Jim Horn, RIAC
# Amy Franklin, Student AffairsJames Huizenga, Health ServicesRyan Smith, Campus Dining Services

# %%
# remove "Web Team"

re.sub(r"^x", "", "xFred Barnhart")
# Out:
# 'Fred Barnhart'
